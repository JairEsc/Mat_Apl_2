# %% [markdown]
# <a href="https://colab.research.google.com/github/JairEsc/Mat_Apl_2/blob/main/Luz_grafs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import table

# %%
sheet_names=['QUERETARO','CANCUN','MONTERREY']

# %%
metrics=['CPLAND','TCA','PAFRAC','ED','LPI','PLAND','CA']
columns=['1985-1995','1986-2005','2006-2015']

# %%
A=pd.read_excel('grafs_luz_2.xlsx',sheet_name='QUERETARO')
B=A.loc[[1,2], '1985-1995':'2006-2015']
B.index=['PLAND','LPI']

# %%
A=pd.read_excel('grafs_luz_2.xlsx',sheet_name='QUERETARO')
ax = plt.subplot(211)
plt.plot(columns,A.loc[A['metric']=='PLAND'].values[0][1:],'-o',label='PLAND')
plt.plot(columns,A.loc[A['metric']=='LPI'].values[0][1:],'-o',label='LPI')
plt.title('Metrics: PLAND, LPI',fontsize=16)
plt.suptitle('Querétaro',fontsize=24, y=1,color='red',)
plt.grid(axis='y');
ax.axes.get_xaxis().set_visible(False)
plt.legend(fontsize=12)
table(ax, B, loc='bottom')
plt.show()

# %%
A.loc[A['metric'] in ['CA','TCA']]
A.loc[A['metric'] in ['ED','CPLAND','PAFRAC']]
